# %% [markdown]
# # Actividades del Modulo 4 | Model Development
# Erick de Jesus Hernandez Cerecedo
# A01066428

# %% [markdown]
# ### Model Development

# %% [markdown]
# In this module:
# - Simple and Multiple Linear Regression
# - Model Evaluation using Visualization
# - Polynomial Regression and Pipelines
# - R-squared and MSE for In-Sample Evaluation
# - Prediction and Decision Making
#
# Model Development
# A model or estimator can be thought of as a mathematical equation used to predict a
# value given one or more other values. Relating one or more independent variables or features to dependent variables.
#
# * Usually the more relevant data you have the more accurate your model is.

# %% [markdown]
# ### Linear Regression and Multiple Linear Regression

# %% [markdown]
# ##### Linear Regression
#
# Linear Regression will refer to one independent variable to make a prediction.
#
# **Simple Linear Regression (or SLR)** is: A method to help us understand the relationship between
# two variables:
# * The predictor (independent) variable x.
# * The target (dependent) variable y.
#
# Y = B0 + b1 x
#
# b0 = The intercept
# b1 = The slope
#
# Fitting a Simple Linear Model Estimator
# * X= Predictor variable
# * y= Target variable
#
# 1. Import linear_model from sickit-learn
# ```python
# # Importancion de librerias
# from sklearn.linear_model import LinearRegression
# ```
#
# 2. Create a Lienar Regression Object using the constructor:
# ```python
# # Creacion de objeto
# lm = LinearRegression()
# ```
#
# 3. Define the predictor variable and target variable
# ```python
# # Definicion de variables
# X = df[['highway-mpg']]
# y = df[['price']]
# ```
#
# 4. Use lm.fit(X, y) to fit the model, i.e fine the parameters b0 and b1
# ```python
# # Fitting the model
# lm.fit(X,y)
# ```
#
# 5. Obtain a prediction
# ```python
# # Obtaining a prediction
# yhat = lm.predict(X)
# ```
#
# **SLR - Estimated Linear Model**
#
# 1. The interception (b0)
# ```python
# # Obtaining interception
# lm.intercept_
# ```
#
# 2. View the slope (b1)
# ```python
# # Obtaining slop
# lm.coef_
# ```
#
# ##### Multiple lineal Regrerssion
#
# Multiple Linear Regression will refer to multiple independent variables to make a prediction.
# Multiple Linear Regression is used to explain the relationship between:
# - One continuous target (Y) variable.
# - Two or more predictor (X) variables.
#
# Yhat = b0 + b1 x1 + b2 x2 + b3 x3 + b4 x4
#
# * b0 = intercept (x=0)
# * b1 = coefficient or parameter of x1
# * b2 = coefficient or parameter of x2
# * and so on...
#
# If we had two variables
#
# Yhat = 1 + 2x1 + 3x2
#
# * The variables 𝑋1 and 𝑋2 can be visualized on a 2D plane
#
# 1. We can extract the 4 predictor variables and store them in the variable Z.
# ```python
# # Extracting predictor variables
# z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]
# ```
#
# 2. Train the model using fit
# ```python
# # Training the model
# lm.fit(z, df['price'])
# ```
#
# 3. Obtaing a prediction
# ```python
# # Obtaining a prediction
# yhat = lm.predict(X)
# ```
#
# 4. Find the intercept (b0)
# ```python
# # Intereception
# lm.intercept_
# ```
#
# 5. Find the coefficients (b1, b2, b3, b4)
# ```python
# # Coefficients
# lm.coef_
# ```

# %% [markdown]
# ### Model Evaluation using Visualization

# %% [markdown]
# ##### Regression Plot
# It gives a good estimate of
# 1. The relationship between two variables.
# 2. The strength of the correlation.
# 3. The direction of the relationship (positive or negative).
#
# What observe in a Regression Plot
# * The horizontal axis is the independent variable.
# * The vertical axis is the dependent variable.
# * Each point represents a different target point.
# * The fitted line represents the predicted value.
#
# ```python
# #
# Import seaborn as sns
#
# sns.regplot(x = "highway-mpg", y = "price", data = df)
# plt.ylim(0,)
# ```
#
# **Residual Plor**
# The residual plot represents the error between the actual values.
# Examining the predicted value and actual value we see a difference.
# ```python
# #
# import seaborn as sns
# sns.residplot(df['highway-mpg'], df['price'])
# ```
#
# **Residual Plor**
# A distribution plot counts the predicted value versus the actual value.
# These plots are extremely useful for visualizing models with more than one independent variable of a feature.
# ```python
# #
# import seaborn as sns
# ax1 = sns.displot(df['price'], hist = False, color="r", label = "Actual Value")
#
# sns.displot(Yhat, hist+False, color="b", label="Fitted Values", ax=ax1)
# ```

# %% [markdown]
# ### Polynomial Regression and Pipelines

# %% [markdown]
# Let’s look into another type of regression model: **the polynomial regression.**
#
# 1. We Transform our data into a polynomial,
# 2. Then use linear regression to fit the parameter.
# 3. Then we will discuss pipelines.
#     * Pipelines are a way to simplify your code.
#
# ##### Polinomial Regressions
# * Polynomial regression is a special case of the general linear regression.
# * This method is beneficial for describing curvilinear relationships.
#
# ##### Curvilinear relationships
# It’s what you get by squaring or setting higher-order terms of the predictor variables in the model, transforming the data.
#
# In a polinomial regression models can be:
# * Quadratic
# * Cubic
# * Higher order
#
# Example
# 1. Calculate Polynomial od 3rd order
# ```python
# #
# f = np.polyfit(x,y,3)
# p = np.polyld(f)
# ```
#
# 2. Print out the model
# ```python
# #
# print(p)
# ```
#
# The preprocessing library in scikit-lear
# ```python
# #
# from sklearn.preprocessing import PolynomialFeatures
# pr = PolynomialFeatures(degree=2, include_bias=False)
# x_polly = pr.fit_transform(x[['horsepower', 'curb-weight']])
# ```
#
# ##### Pipelines
# There are many steps to getting a prediction, for example, Normalization, Polynomial transform, and Linear regression.
# We simplify the process using a pipeline.
# ```python
# #
# from sklearn.preprocessing import PolynomailFeature
# from sklearn.linear_model import Linear Regression
# from sklearn.preprocessing import StandarScaler
#
# # Pipeline constructor
# input = [('scale', StrandarScaler(), ('polynomial', PolynomailFatures(degree=2),('model', LinearRegression())))]
#
# pipe = Pipeline(input)
# # train the pipeline
# pipe.trian(X['horsepower', 'curb-weight', 'engine-size', 'highway-mpg'], y)
# Yhat = pipe.predict(X[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])
# ```

# %% [markdown]
# ### Measures for In-Sample Evaluation

# %% [markdown]
# These measures are a way to numerically determine how good the model fits on our data.
#
# Two important measures that we often use to determine the fit of a model are:
# * Mean Square Error (MSE)
# * R-squared.
#
#
# ##### Mean Square Error (MSE)
# To measure the MSE, we find the difference between the actual value y and the predicted
# value yhat then square it.
# ```python
# #
# from sklearn.metrics import mean_squared_error
# mean_squared_error(df['price'], Y_predict_simple_fit)
# ```
#
#
# ##### R-squared
# R-squared is also called the coefficient of determination.
# It’s a measure to determine how close the data is to the fitted regression line.
#
# R2 = (1 - (MSE-regresion-line / MSE-average-data))
#
# ```python
# #
# X = df[['highway-mpg']]
# y = df['price']
# lm.fit(X, y)
#
# lm.score(X, y)
# ```

# %% [markdown]
# ### Prediction and Decision Making

# %% [markdown]
# 1. The first thing you should do is make sure your model results make sense.
# 2. You should always use Visualization,
# 3. Numerical measures for evaluation,
# 4. Comparing between different models.
#
# Example
# 1. Train the model
# ```python
# #
# lm.fit(df['highway-mpg'], df['prices'])
# ```
#
# 2. Train the model
# ```python
# #
# lm.predict(30)
# ```
#
# To predict values in specified range
# 1. Import numpy
# 2. Use numpy functions arrange to generate a sequence from 1 to 100
# ```python
# #
# import numpy as np
#
# new_input = np.arange(1, 101, 1).reshape(-1,1)
# ```
#
# Outputs to predict model
# ```python
# #
# yhat = lm.predict(new_input)
# ```

# %% [markdown]
# ### Lab 4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    # Legacy Python that doesn't verify HTTPS certificates by default
    pass
else:
    # Handle target environment that doesn't support HTTPS verification
    ssl._create_default_https_context = _create_unverified_https_context

# URL data set auto
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv"

# Headers array
headers = ["symboling","normalized-losses","make","fuel-type","aspiration","num-of-doors","body-style","drive-wheels","engine-location","wheel-base","length","width","height","curb-weight","engine-type","num-of-cylinders","engine-size","fuel-system","bore","stroke","compression-ratio","horsepower","peak-rpm","city-mpg","highway-mpg","price"]

# Read the CSV data set from the url "read_csv"
df = pd.read_csv(url)

# Show the first 5 records from the dataset
df.head(5)
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %% [markdown]
# 1. Linear Regression and Multiple Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm
# Out:
# LinearRegression()

# %%
# Variable definicion
X = df[['highway-mpg']]
Y = df['price']

# %%
# Fitting the model
lm.fit(X,Y)
# Out:
# LinearRegression()

# %%
# Output a prediction
Yhat=lm.predict(X)
Yhat[0:5]
# Out:
# array([16236.50464347, 16236.50464347, 17058.23802179, 13771.3045085 ,
#        20345.17153508])

# %%
# Intercept of the prediction
lm.intercept_
# Out:
# 38423.3058581574

# %%
# Coefficient
lm.coef_
# Out:
# array([-821.73337832])

# %% [markdown]
# ### **Question #1 A:**
#
# Create a linear regression object called "lm1".

# %%
lm1 = LinearRegression()
lm1
# Out:
# LinearRegression()

# %% [markdown]
# ### **Question #1 B:**
#
# Train the model using "engine-size" as the independent variable and "price" as the dependent variable?

# %%
lm1.fit(df[['engine-size']], df[['price']])
lm1
# Out:
# LinearRegression()

# %% [markdown]
# ### **Question #1 C:**
#
# Find the slope and intercept of the model.

# %%
print(lm1.coef_)
print(lm1.intercept_)
# Out:
# [[166.86001569]]
# [-7963.33890628]

# %% [markdown]
# ### **Question #1 D:**
#
# What is the equation of the predicted line? You can use x and yhat or "engine-size" or "price".

# %%
Yhat=-7963.34 + 166.86*X

Price=-7963.34 + 166.86*df['engine-size']

# %%
# Multi Linear Regression
Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]
lm.fit(Z, df['price'])
print(lm.intercept_)
print(lm.coef_)
# Out:
# -15806.62462632922
# [53.49574423  4.70770099 81.53026382 36.05748882]

# %% [markdown]
# ### **Question #2 A:**
#
# Create and train a Multiple Linear Regression model "lm2" where the response variable is "price", and the predictor variable is "normalized-losses" and "highway-mpg".

# %%
lm2 = LinearRegression()
lm2.fit(df[['normalized-losses' , 'highway-mpg']],df['price'])
# Out:
# LinearRegression()

# %% [markdown]
# ### **Question #2 B:**
#
# Find the coefficient of the model.

# %%
lm2.coef_
# Out:
# array([   1.49789586, -820.45434016])

# %% [markdown]
# 2. Model Evaluation Using Visualization

# %%
# import the visualization package: seaborn
import seaborn as sns
# %matplotlib inline 

width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x="highway-mpg", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 48189.21803690144)

# %%
plt.figure(figsize=(width, height))
sns.regplot(x="peak-rpm", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 47414.1)

# %% [markdown]
# ### **Question #3:**
#
# Given the regression plots above, is "peak-rpm" or "highway-mpg" more strongly correlated with "price"? Use the method ".corr()" to verify your answer.

# %%
df[["peak-rpm","highway-mpg","price"]].corr()
# Out:
#              peak-rpm  highway-mpg     price
# peak-rpm     1.000000    -0.058598 -0.101616
# highway-mpg -0.058598     1.000000 -0.704692
# price       -0.101616    -0.704692  1.000000

# %%
# Residual Plot
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(x=df['highway-mpg'],y=df['price'])
plt.show()

# %%
# Multiple Linear Regression
Y_hat = lm.predict(Z)

plt.figure(figsize=(width, height))


ax1 = sns.distplot(df['price'], hist=False, color="r", label="Actual Value")
sns.distplot(Y_hat, hist=False, color="b", label="Fitted Values" , ax=ax1)


plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price (in dollars)')
plt.ylabel('Proportion of Cars')

plt.show()
plt.close()
# Out:
# /var/folders/6k/743ttrkx5pqf092zt1_xq4dr0000gn/T/ipykernel_7698/4161610076.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(df['price'], hist=False, color="r", label="Actual Value")
# /var/folders/6k/743ttrkx5pqf092zt1_xq4dr0000gn/T/ipykernel_7698/4161610076.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# 3. Polynomial Regression and Pipelines

# %%
def PlotPolly(model, independent_variable, dependent_variabble, Name):
    x_new = np.linspace(15, 55, 100)
    y_new = model(x_new)

    plt.plot(independent_variable, dependent_variabble, '.', x_new, y_new, '-')
    plt.title('Polynomial Fit with Matplotlib for Price ~ Length')
    ax = plt.gca()
    ax.set_facecolor((0.898, 0.898, 0.898))
    fig = plt.gcf()
    plt.xlabel(Name)
    plt.ylabel('Price of Cars')

    plt.show()
    plt.close()

# %%
x = df['highway-mpg']
y = df['price']

f = np.polyfit(x, y, 3)
p = np.poly1d(f)
print(p)
# Out:
#         3         2
# -1.557 x + 204.8 x - 8965 x + 1.379e+05

# %%
PlotPolly(p, x, y, 'highway-mpg')

# %%
np.polyfit(x, y, 3)
# Out:
# array([-1.55663829e+00,  2.04754306e+02, -8.96543312e+03,  1.37923594e+05])

# %% [markdown]
# ### **Question #4:**
#
# Create 11 order polynomial model with the variables x and y from above.

# %%
f1 = np.polyfit(x, y, 11)
p1 = np.poly1d(f1)
print(p1)
PlotPolly(p1,x,y, 'Highway MPG')
# Out:
#             11             10             9           8         7
# -1.243e-08 x  + 4.722e-06 x  - 0.0008028 x + 0.08056 x - 5.297 x
#           6        5             4             3             2
#  + 239.5 x - 7588 x + 1.684e+05 x - 2.565e+06 x + 2.551e+07 x - 1.491e+08 x + 3.879e+08

# %%
from sklearn.preprocessing import PolynomialFeatures
pr=PolynomialFeatures(degree=2)

Z_pr=pr.fit_transform(Z)

Z.shape
Z_pr.shape
# Out:
# (201, 15)

# %%
# Pipeline
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

Input=[('scale',StandardScaler()), ('polynomial', PolynomialFeatures(include_bias=False)), ('model',LinearRegression())]
pipe=Pipeline(Input)
pipe
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %%
Z = Z.astype(float)
pipe.fit(Z,y)
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %%
ypipe=pipe.predict(Z)
ypipe[0:4]
# Out:
# array([13102.74784201, 13102.74784201, 18225.54572197, 10390.29636555])

# %% [markdown]
# ### **Question #5:**
#
# Create a pipeline that standardizes the data, then produce a prediction using a linear regression model using the features Z and target y.

# %%
Input=[('scale',StandardScaler()),('model',LinearRegression())]

pipe=Pipeline(Input)

pipe.fit(Z,y)

ypipe=pipe.predict(Z)
ypipe[0:10]
# Out:
# array([13699.11161184, 13699.11161184, 19051.65470233, 10620.36193015,
#        15521.31420211, 13869.66673213, 15456.16196732, 15974.00907672,
#        17612.35917161, 10722.32509097])

# %% [markdown]
# 4. Measures for In-Sample Evaluation

# %%
#highway_mpg_fit
lm.fit(X, Y)
# Find the R^2
print('The R-square is: ', lm.score(X, Y))
# Out:
# The R-square is:  0.4965911884339176

# %%
Yhat=lm.predict(X)
print('The output of the first four predicted value is: ', Yhat[0:4])
# Out:
# The output of the first four predicted value is:  [16236.50464347 16236.50464347 17058.23802179 13771.3045085 ]

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(df['price'], Yhat)
print('The mean square error of price and predicted value is: ', mse)
# Out:
# The mean square error of price and predicted value is:  31635042.944639888

# %%
# Model 2: Multiple Linear Regression
# fit the model 
lm.fit(Z, df['price'])
# Find the R^2
print('The R-square is: ', lm.score(Z, df['price']))
# Out:
# The R-square is:  0.8093562806577457

# %%
Y_predict_multifit = lm.predict(Z)

print('The mean square error of price and predicted value using multifit is: ', \
      mean_squared_error(df['price'], Y_predict_multifit))
# Out:
# The mean square error of price and predicted value using multifit is:  11980366.87072649

# %%
# Model 3: Polynomial Fit
from sklearn.metrics import r2_score

r_squared = r2_score(y, p(x))
print('The R-square value is: ', r_squared)
# Out:
# The R-square value is:  0.674194666390652

# %%
# MSE
mean_squared_error(df['price'], p(x))
# Out:
# 20474146.426361218

# %% [markdown]
# 5. Prediction and Decision Making

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline 

new_input=np.arange(1, 100, 1).reshape(-1, 1)
lm.fit(X, Y)

yhat=lm.predict(new_input)
yhat[0:5]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([37601.57247984, 36779.83910151, 35958.10572319, 35136.37234487,
#        34314.63896655])

# %%
plt.plot(new_input, yhat)
plt.show()

# %% [markdown]
# ###  Graded Review Questions

# %% [markdown]
# Evidencia de preguntas
# ![Resultado de cuestionario modulo 1](assets/evidencia.png "Resultado de cuestionario modulo 1")

# %% [markdown]
# ###
